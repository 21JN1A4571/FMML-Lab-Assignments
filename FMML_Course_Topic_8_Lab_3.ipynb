# %% [markdown]
# <a href="https://colab.research.google.com/github/21JN1A4571/FMML-Lab-Assignments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 16:52:36--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   214MB/s    in 0.3s
#
# 2024-03-31 16:52:39 (214 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 8844   1512.00112v1  Characterizing relationships between people is...    cs
# 22279  1511.06120v1  In clinical and neuroscientific studies, syste...  stat
# 6928   1707.07287v2  We suggest a general approach to quantificatio...  stat
# 21835   1302.7220v2  Gaussian process is a very promising novel tec...  stat
# 22989  1712.09641v1  A novel quantile Fourier neural network is pre...  stat
# ...             ...                                                ...   ...
# 32825  1508.03865v2  To increase efficacy in traditional classroom ...    cs
# 16215  1610.09722v1  In order to extract event information from tex...    cs
# 7265   1711.05560v1  We present the Variational Adaptive Newton (VA...  stat
# 17013  1707.09406v1  The lack of large realistic datasets presents ...    cs
# 31051  1802.02213v1  Morphological tissue patterns in RCM images ar...    cs
#
#                                                    title  year  \
# 8844   Inferring Interpersonal Relations in Narrative...  2015
# 22279      The Kernel Two-Sample Test for Brain Networks  2015
# 6928   Learning uncertainty in regression tasks by ar...  2017
# 21835  A New Monte Carlo Based Algorithm for the Gaus...  2013
# 22989  A Composite Quantile Fourier Neural Network fo...  2017
# ...                                                  ...   ...
# 32825                                  Predicting Grades  2015
# 16215  Represent, Aggregate, and Constrain: A Novel A...  2016
# 7265   Variational Adaptive-Newton Method for Explora...  2017
# 17013  Online Deception Detection Refueled by Real Wo...  2017
# 31051  A Multiresolution Deep Learning Framework for ...  2018
#
#                                                 keywords
# 8844   [characterizing, relationships, fundamental, u...
# 22279  [neuroscientific, systematic, differences, pop...
# 6928   [quantification, different, uncertainty, regre...
# 21835  [promising, technology, regression, classifica...
# 22989  [presented, nonparametric, probabilistic, fore...
# ...                                                  ...
# 32825  [traditional, classroom, automated, supporting...
# 16215  [information, accurately, interpret, informati...
# 7265   [variational, optimization, especially, explor...
# 17013  [realistic, bottleneck, deception, detection, ...
# 31051  [morphological, diagnosis, melanocytic, multir...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 8844     [characterizing, relationships, fundamental, u...
# 22279    [neuroscientific, systematic, differences, pop...
# 6928     [quantification, different, uncertainty, regre...
# 21835    [promising, technology, regression, classifica...
# 22989    [presented, nonparametric, probabilistic, fore...
#                                ...
# 11624    [identifying, measurable, indicators, conditio...
# 3231     [dictionary, algorithms, successfully, reconst...
# 12928    [annotated, repository, represented, multitude...
# 10583    [decomposing, orthogonal, statistics, processi...
# 7424     [significantly, algorithm, presented, procedur...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8644 words.
# Out of those 4577 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="33bf64b4-b33a-4de8-9377-1650b6a024a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33bf64b4-b33a-4de8-9377-1650b6a024a0")) {                    Plotly.newPlot(                        "33bf64b4-b33a-4de8-9377-1650b6a024a0",                        [{"x":["competitive","summaries","relations","reduction","inferring","structured","narrative","considers","relationships","structure","characters","formulate","narratives","community","isolation","characterizing","regularities","prediction","understanding","wikipedia","clustering","fundamental","interpersonal","linguistic","triangles","investigated","approaches","different","systematic","processes","populations","frequency","represented","classifier","computation","classification","algorithmic","simulation","additionally","intermediate","characterize","considerations","providing","neuroimaging","experiments","differences","discriminate","simultaneously","hyperparameters","particular","estimating","performed","predictions","probability","counterparts","likelihood","maximization","classical","uncertainty","regression","artificial","simultaneous","distribution","quantifies","quantification","transforms","properties","simplicity","evaluates","algorithm","promising","technology","beneficial","solutions","integrals","evaluating","acceptancerejection","encounter","reliability","derivation","intractable","multivariate","procedure","bootstrap","nonparametric","introduces","extrapolation","forecasting","quantiles","autoregressive","empirical","probabilistic","presented","seasonality","composite","effectively","anonymized","protecting","predictor","representations","representation","motivated","anonymization","organizations","objective","preventing","introduce","correspond","predicted","adversarial","sensitive","architecture","demonstrate","individuals","sentiment","information","theoretical","investigates","statistical","predictive","variables","benchmark","mechanism","gradients","numerically","approximation","performance","auxiliary","development","stochastic","exploiting","optimisation","observations","encouraging","innovation","construction","reconstruction","efficient","interpolation","handcrafted","complexity","significantly","operation","convolution","specifically","computational","magnitude","upscaling","available","resolution","extracted","convolutional","assumption","incremental","heterogeneous","superiority","homogeneous","combination","determine","unfortunately","extensive","neighbors","guaranteed","framework","automatically","efficiency","propagation","propagate","effectiveness","inference","connected","extensively","homophily","processing","commitment","describes","commitments","execution","significant","operations","discussions","adaptable","challenge","adaptation","implements","concurrently","technologies","consistency","reinforcement","decreases","densities","asymptotic","dynamical","optimizing","population","preferences","qualitative","application","reasoning","optimization"],"y":[125,18,105,88,28,110,8,41,67,327,28,68,4,86,5,16,13,217,169,26,143,84,2,83,1,58,436,732,32,87,9,50,82,143,148,535,35,76,64,33,46,13,93,5,616,49,14,113,11,264,52,133,87,157,17,75,28,108,88,107,133,28,214,8,11,17,218,21,11,749,120,52,18,153,2,57,0,8,14,18,29,24,132,5,20,74,1,15,1,7,141,179,186,0,7,133,3,1,13,237,338,61,1,11,163,6,351,28,52,114,55,247,567,29,51,693,140,28,169,54,142,206,113,35,13,109,898,23,133,127,79,29,69,31,8,72,92,399,17,15,215,252,39,47,163,276,51,2,306,136,125,394,72,27,44,42,27,122,72,34,151,18,34,547,192,178,64,4,212,226,74,40,3,304,5,83,2,37,258,84,12,3,157,67,13,4,19,51,117,9,15,25,26,51,53,39,56,240,132,316],"type":"bar"},{"x":["competitive","summaries","relations"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4577,), (4577, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8125

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Toward</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.453125);'>automated</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>complex</span> <span style=''>diseases</span> <span style=''>in</span> <span style=''>genome</span> <span style=''>wide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>association</span> <span style=''>studies</span> <span style=''>using</span> <span style=''>genetic</span> <span style='background-color:rgba(0, 255, 0, 0.35051546391752586);'>programming</span> <br/><br/><span style=''>Machine</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>been</span> <span style=''>gaining</span> <span style=''>traction</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>to</span> <span style=''>meet</span> <span style=''>the</span> <span style=''>demand</span> <span style=''>for</span> <span style=''>tools</span> <span style=''>that</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>analyze</span> <span style=''>and</span> <span style=''>make</span> <span style=''>sense</span> <span style=''>of</span> <span style=''>the</span> <span style=''>ever</span> <span style=''>growing</span> <span style='background-color:rgba(0, 255, 0, 0.4400000000000001);'>databases</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biomedical</span> <span style=''>data</span> <span style=''>in</span> <span style=''>health</span> <span style=''>care</span> <span style=''>systems</span> <span style=''>around</span> <span style=''>the</span> <span style=''>world</span> <span style=''>However</span> <span style='background-color:rgba(0, 255, 0, 0.4615384615384616);'>effectively</span> <span style=''>using</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>requires</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considerable</span> <span style=''>domain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expertise</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>a</span> <span style=''>barrier</span> <span style=''>of</span> <span style=''>entry</span> <span style=''>for</span> <span style=''>bioinformaticians</span> <span style=''>new</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>data</span> <span style=''>science</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Therefore</span> <span style=''>off</span> <span style=''>the</span> <span style=''>shelf</span> <span style=''>tools</span> <span style=''>that</span> <span style=''>make</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3600000000000001);'>accessible</span> <span style=''>can</span> <span style=''>prove</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>invaluable</span> <span style=''>for</span> <span style=''>bioinformaticians</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>we</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>an</span> <span style=''>open</span> <span style=''>source</span> <span style=''>pipeline</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>tool</span> <span style=''>(TPOT</span> <span style=''>MDR)</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>genetic</span> <span style='background-color:rgba(0, 255, 0, 0.35051546391752586);'>programming</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.41697416974169743);'>automatically</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalization</span> <span style=''>error</span> <span style=''>bounds</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style=''>models</span> <br/><br/><span style=''>We</span> <span style=''>derive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>error</span> <span style=''>bounds</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>univariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style=''>(AR)</span> <span style=''>models</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>imposing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationarity</span> <span style=''>is</span> <span style=''>enough</span> <span style=''>to</span> <span style=''>control</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>without</span> <span style=''>further</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>This</span> <span style=''>lets</span> <span style=''>us</span> <span style=''>use</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>for</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>our</span> <span style=''>methods</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicting</span> <span style=''>interest</span> <span style=''>rate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>movements</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dependent</span> <span style=''>Kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximation</span> <span style=''>using</span> <span style=''>Pseudo</span> <span style=''>Random</span> <span style=''>Fourier</span> <span style=''>Features</span> <br/><br/><span style=''>Kernel</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>powerful</span> <span style=''>and</span> <span style=''>flexible</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>many</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>Due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>evaluations</span> <span style=''>in</span> <span style=''>kernel</span> <span style=''>methods</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>grows</span> <span style=''>as</span> <span style=''>the</span> <span style=''>data</span> <span style=''>size</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increases</span> <span style=''>thus</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicability</span> <span style=''>of</span> <span style=''>kernel</span> <span style=''>methods</span> <span style=''>is</span> <span style=''>limited</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>datasets</span> <span style=''>Random</span> <span style=''>Fourier</span> <span style=''>Features</span> <span style=''>(RFF)</span> <span style=''>has</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>to</span> <span style=''>scale</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>method</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>datasets</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.4098360655737705);'>approximating</span> <span style=''>kernel</span> <span style=''>function</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>randomized</span> <span style=''>Fourier</span> <span style=''>features</span> <span style=''>While</span> <span style=''>this</span> <span style=''>method</span> <span style=''>proved</span> <span style=''>very</span> <span style=''>popular</span> <span style=''>still</span> <span style=''>it</span> <span style=''>exists</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>shortcomings</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.4615384615384616);'>effectively</span> <span style=''>used</span> <span style=''>As</span> <span style=''>RFF</span> <span style=''>samples</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>randomized</span> <span style=''>features</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>of</span> <span style=''>training</span> <span style=''>data</span> <span style=''>it</span> <span style=''>requires</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expansions</span> <span style=''>to</span> <span style=''>have</span> <span style=''>sim ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Pairwise</span> <span style=''>Loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>with</span> <span style=''>pairwise</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>is</span> <span style=''>a</span> <span style=''>crucial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>in</span> <span style=''>building</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>learning</span> <span style=''>system</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximizes</span> <span style=''>the</span> <span style=''>area</span> <span style=''>under</span> <span style=''>the</span> <span style=''>Receiver</span> <span style=''>Operator</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Characteristic</span> <span style=''>(ROC)</span> <span style=''>curve</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>online</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>pairwise</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>existing</span> <span style=''>proof</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>bounds</span> <span style=''>of</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>univariate</span> <span style=''>loss</span> <span style=''>can</span> <span style=''>not</span> <span style=''>be</span> <span style=''>directly</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>pairwise</span> <span style=''>losses</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>the</span> <span style=''>first</span> <span style=''>result</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>the</span> <span style=''>average</span> <span style=''>risk</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypotheses</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style=''>online</span> <span style=''>learner</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>an</span> <span style=''>easily</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistic</span> <span style=''>and</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09819851642529141)
# 	processing (0.10738255033557047)
# 	architecture (0.087248322147651)
# 	experimental (0.13246202755210174)
# 	information (0.244789826916284)
# 	segmentation (0.07947721653126104)
# 	detection (0.12398445778876722)
# 	different (0.2585658777817026)
# 	recognition (0.13246202755210174)
# 	convolutional (0.13917343694807488)
#
# Some Statistics words are:
# 	stochastic (0.13763331640426613)
# 	statistical (0.1569324530218385)
# 	variables (0.14982224479431183)
# 	estimation (0.16759776536312848)
# 	theoretical (0.15947181310309802)
# 	distribution (0.18943626206196038)
# 	algorithm (0.38649060436769933)
# 	dimensional (0.18334179786693752)
# 	inference (0.20568816658202133)
# 	regression (0.19349923819197562)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee18e0fc-2a15-4632-9549-4459fc10927a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee18e0fc-2a15-4632-9549-4459fc10927a")) {                    Plotly.newPlot(                        "ee18e0fc-2a15-4632-9549-4459fc10927a",                        [{"x":["competitive","summaries","relations","reduction","inferring","structured","narrative","considers","relationships","structure","characters","formulate","narratives","community","isolation","characterizing","regularities","prediction","understanding","wikipedia","clustering","fundamental","interpersonal","linguistic","triangles","investigated","approaches","different","systematic","processes","populations","frequency","represented","classifier","computation","classification","algorithmic","simulation","additionally","intermediate","characterize","considerations","providing","neuroimaging","experiments","differences","discriminate","simultaneously","hyperparameters","particular","estimating","performed","predictions","probability","counterparts","likelihood","maximization","classical","uncertainty","regression","artificial","simultaneous","distribution","quantifies","quantification","transforms","properties","simplicity","evaluates","algorithm","promising","technology","beneficial","solutions","integrals","evaluating","acceptancerejection","encounter","reliability","derivation","intractable","multivariate","procedure","bootstrap","nonparametric","introduces","extrapolation","forecasting","quantiles","autoregressive","empirical","probabilistic","presented","seasonality","composite","effectively","anonymized","protecting","predictor","representations","representation","motivated","anonymization","organizations","objective","preventing","introduce","correspond","predicted","adversarial","sensitive","architecture","demonstrate","individuals","sentiment","information","theoretical","investigates","statistical","predictive","variables","benchmark","mechanism","gradients","numerically","approximation","performance","auxiliary","development","stochastic","exploiting","optimisation","observations","encouraging","innovation","construction","reconstruction","efficient","interpolation","handcrafted","complexity","significantly","operation","convolution","specifically","computational","magnitude","upscaling","available","resolution","extracted","convolutional","assumption","incremental","heterogeneous","superiority","homogeneous","combination","determine","unfortunately","extensive","neighbors","guaranteed","framework","automatically","efficiency","propagation","propagate","effectiveness","inference","connected","extensively","homophily","processing","commitment","describes","commitments","execution","significant","operations","discussions","adaptable","challenge","adaptation","implements","concurrently","technologies","consistency","reinforcement","decreases","densities","asymptotic","dynamical","optimizing","population","preferences","qualitative","application","reasoning","optimization","knowledge","representing","quantitative","programming","restoring","plasticity","maximizing","foundation","incentives","biologically","investigate","perspective","backpropagate","plausible","usefulness","utilities","faithfully","discretizing","according","hierarchical","dirichlet","restaurant","alleviates","formulation","documents","generalization","management","projection","conservation","landscape","effective","satellite","quantitatively","techniques","advantages","unstructured","infrequently","inherently","interpreting","infectious","questions","interpreted","estimations","comprehensive","comparing","disaggregation","expensive","estimation","projections","individually","aggregating","qualitati ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	acceptancerejection
# 	seasonality
# 	revolutionize
# 	discriminators
# 	smoothers
# 	newsgroup
# 	formalizes
# 	interrelated
# 	concordance
# 	periodicity
# 	blockmodel
# 	postulated
# 	covariates
# 	basketball
# 	factorizes
# 	changepoint
# 	changepoints
# 	advocates
# 	crowdworkers
# 	reconstructive
# Some words which never appear in Statistics papers:
# 	narrative
# 	characters
# 	interpersonal
# 	handcrafted
# 	homophily
# 	commitment
# 	commitments
# 	restoring
# 	discretizing
# 	infrequently
# 	computability
# 	characterised
# 	syntactic
# 	paralyzed
# 	assistive
# 	messaging
# 	persuasion
# 	argumentative
# 	argumentation
# 	valuation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0407151762094447e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7633333333333333
